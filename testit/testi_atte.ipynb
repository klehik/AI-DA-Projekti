# %%
import pandas as pd

df = pd.read_csv("data/LBNL_file.csv", low_memory=False)


df.head()
# Out:
#                 data_provider_1 data_provider_2 system_ID_1 system_ID_2  \
# 0  Arkansas State Energy Office           -9999       -9999       -9999
# 1  Arkansas State Energy Office           -9999       -9999       -9999
# 2  Arkansas State Energy Office           -9999       -9999       -9999
# 3  Arkansas State Energy Office           -9999       -9999       -9999
# 4  Arkansas State Energy Office           -9999       -9999       -9999
#
#       installation_date  system_size_DC  total_installed_price  \
# 0  29-Apr-2010 00:00:00           2.016                14558.0
# 1  26-Apr-2010 00:00:00           3.360                26096.0
# 2  20-Apr-2010 00:00:00          13.440                91139.0
# 3  21-Apr-2010 00:00:00           5.520                40043.0
# 4  22-Apr-2010 00:00:00           2.530                21497.0
#
#    rebate_or_grant customer_segment  expansion_system  ...  \
# 0              0.0              RES                 0  ...
# ...

# %%
df.info(show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000000 entries, 0 to 999999
# Data columns (total 78 columns):
#  #   Column                           Non-Null Count    Dtype
# ---  ------                           --------------    -----
#  0   data_provider_1                  1000000 non-null  object
#  1   data_provider_2                  1000000 non-null  object
#  2   system_ID_1                      1000000 non-null  object
#  3   system_ID_2                      1000000 non-null  object
#  4   installation_date                1000000 non-null  object
#  5   system_size_DC                   1000000 non-null  float64
#  6   total_installed_price            1000000 non-null  float64
#  7   rebate_or_grant                  1000000 non-null  float64
#  8   customer_segment                 1000000 non-null  object
#  9   expansion_system                 1000000 non-null  int64
#  10  multiple_phase_system            1000000 non-null  int64
# ...

# %%
df.describe().T
# Out:
#                                      count          mean            std  \
# system_size_DC                   1000000.0   -103.848630    1059.276396
# total_installed_price            1000000.0  29290.866715  174230.776901
# rebate_or_grant                  1000000.0    841.183410   19009.872435
# expansion_system                 1000000.0      0.009305       0.096013
# multiple_phase_system            1000000.0      0.004546       0.067271
# new_construction                 1000000.0  -7928.710328    4051.581257
# tracking                         1000000.0  -1005.494469    3007.154605
# ground_mounted                   1000000.0  -2405.119393    4273.687924
# third_party_owned                1000000.0   -825.799579    2752.945805
# self_installed                   1000000.0   -444.362165    2060.572183
# azimuth_1                        1000000.0  -3026.225782    4735.312003
# azimuth_2                        1000000.0  -9527.363641    2140.992057
# ...

# %%
df["system_size_DC"].value_counts()
# Out:
# -9999.00000    11308
#  6.00000        6506
#  5.04000        6431
#  5.20000        5704
#  3.00000        5453
#                ...
#  3.16250           1
#  1.15830           1
#  15.62804          1
#  6.12370           1
#  710.80000         1
# Name: system_size_DC, Length: 36031, dtype: int64

# %%
df["output_capacity_inverter_3"].value_counts()
# Out:
# -9999.000    997825
#  0.215          239
#  3.000          216
#  6.000          199
#  5.000          193
#               ...
#  125.000          1
#  9.994            1
#  25.000           1
#  2.962            1
#  11.995           1
# Name: output_capacity_inverter_3, Length: 102, dtype: int64

# %%
df["built_in_meter_inverter_3"].value_counts()
# Out:
# -9999    997304
#  1         1777
#  0          919
# Name: built_in_meter_inverter_3, dtype: int64

# %%
df["state"].value_counts()
# Out:
# CA    998971
# AZ       924
# AR       105
# Name: state, dtype: int64

# %%
df = df[df['system_size_DC'] != -9999]
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 988692 entries, 0 to 999999
# Data columns (total 78 columns):
#  #   Column                           Non-Null Count   Dtype
# ---  ------                           --------------   -----
#  0   data_provider_1                  988692 non-null  object
#  1   data_provider_2                  988692 non-null  object
#  2   system_ID_1                      988692 non-null  object
#  3   system_ID_2                      988692 non-null  object
#  4   installation_date                988692 non-null  object
#  5   system_size_DC                   988692 non-null  float64
#  6   total_installed_price            988692 non-null  float64
#  7   rebate_or_grant                  988692 non-null  float64
#  8   customer_segment                 988692 non-null  object
#  9   expansion_system                 988692 non-null  int64
#  10  multiple_phase_system            988692 non-null  int64
# ...

# %%
df["state"].value_counts()
# Out:
# CA    987664
# AZ       923
# AR       105
# Name: state, dtype: int64

# %%
import seaborn as sns

#df["customer_segment"] = df[df["customer_segment"].isin(["RES","COM"])]

# %%
df.filter(items=['output_capacity_inverter_1',
       'output_capacity_inverter_2', 'output_capacity_inverter_3']).max(1)
# Out:
# 0            0.19
# 1            0.19
# 2            0.19
# 3            0.19
# 4            0.19
#            ...
# 999995     250.00
# 999996   -9999.00
# 999997   -9999.00
# 999998   -9999.00
# 999999   -9999.00
# Length: 988692, dtype: float64

# %%
#df_res = df_res.groupby(["customer_segment"])["state"].count()
#df_res

df
# Out:
#                      data_provider_1 data_provider_2 system_ID_1 system_ID_2  \
# 0       Arkansas State Energy Office           -9999       -9999       -9999
# 1       Arkansas State Energy Office           -9999       -9999       -9999
# 2       Arkansas State Energy Office           -9999       -9999       -9999
# 3       Arkansas State Energy Office           -9999       -9999       -9999
# 4       Arkansas State Energy Office           -9999       -9999       -9999
# ...                              ...             ...         ...         ...
# 999995        Arizona Public Service           -9999       D1117       -9999
# 999996        Arizona Public Service           -9999       D1036       -9999
# 999997        Arizona Public Service           -9999       D1575       -9999
# 999998        Arizona Public Service           -9999       R1286       -9999
# 999999        Arizona Public Service           -9999       R1194       -9999
#
# ...

# %%
df_test = df[["inverter_quantity_1", "inverter_quantity_2", "inverter_quantity_3","inverter_manufacturer_1","inverter_manufacturer_2","inverter_manufacturer_3"]]

df_test = df_test[(df_test["inverter_quantity_2"] != -9999.0) & (df_test["inverter_quantity_3"] != -9999.0 )]

df_test


#df.filter(items=['output_capacity_inverter_1',
      # 'output_capacity_inverter_2', 'output_capacity_inverter_3']).max(1)
# Out:
#         inverter_quantity_1  inverter_quantity_2  inverter_quantity_3  \
# 1719                      5                    2                    1
# 2799                      5                    3                   11
# 3040                      1                    1                    1
# 3811                      6                    4                    1
# 4830                      2                    1                    1
# ...                     ...                  ...                  ...
# 996511                    1                    2                    1
# 997476                    1                    1                    1
# 997921                    3                    1                    1
# 998464                    6                   28                   14
# 998535                   98                    4                    4
#
#             inverter_manufacturer_1      inverter_manufacturer_2  \
# ...

# %%
#df.iloc[2799][70:91]
# Out:
# -9999    954254
#  1        30651
#  2         1580
#  3          417
#  4          253
#           ...
#  69           1
#  136          1
#  100          1
#  44           1
#  50           1
# Name: inverter_quantity_2, Length: 65, dtype: int64
